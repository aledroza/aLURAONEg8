# %% [markdown]
# <a href="https://colab.research.google.com/github/aledroza/aLURAONEg8/blob/main/Copia_de_AluraStoreLatam_ALEDROZA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
#tienda2.head()
#tienda3.head()
#tienda4.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# Calculando el promedio de Clasificacion de los clientes de las 4 tiendas.

# %%
# prompt: crear un codigo que analice cual es el promedio de clasificacion de los clientes en las 4 tiendas
import pandas as pd
# definiendo tiendas
url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Concatenar los dataframes de las tiendas
tiendas_df = pd.concat([tienda, tienda2, tienda3, tienda4])

# Imprimir los nombres de las columnas para verificar el nombre correcto de la columna de clasificación
# print("Columnas disponibles en el DataFrame concatenado:")
# print(tiendas_df.columns)

# Reemplaza 'NombreDeLaColumnaCorrecto' con el nombre exacto de la columna de clasificación que encuentres en el output anterior.
# Por ejemplo, si la columna se llama 'Rating', cambia 'NombreDeLaColumnaCorrecto' a 'Rating'.
# Si la columna se llama 'Calificacion_Cliente', cambia 'NombreDeLaColumnaCorrecto' a 'Calificacion_Cliente'.
try:
    # Intenta usar el nombre de columna que crees que es el correcto.
    # Si el print de columnas te muestra un nombre diferente, úsalo aquí.
    promedio_clasificacion = tiendas_df['Calificación'].mean() # Asumiendo que la columna se llama 'Calificación' (sin mayúscula inicial en la base de datos)
except KeyError:
    # Si 'Calificación' tampoco funciona, puedes probar con otros nombres comunes o referirte al output de tiendas_df.columns
    # print("La columna 'Calificación' no fue encontrada. Por favor, verifica el nombre correcto de la columna en el output de tiendas_df.columns")
    # Por ahora, puedes intentar con 'clasificacion' si crees que podría ser ese el nombre
    try:
        promedio_clasificacion = tiendas_df['clasificacion'].mean()
    except KeyError:
        print("No se encontró una columna de clasificación común. Por favor, examine el output de tiendas_df.columns y actualice el código con el nombre correcto.")
        promedio_clasificacion = None # O manejar el error de otra forma

if promedio_clasificacion is not None:
    print(f"El promedio de clasificación de los clientes en las 4 tiendas es: {promedio_clasificacion}")
# Out:
# El promedio de clasificación de los clientes en las 4 tiendas es: 4.014520402755696

# %% [markdown]
# #1. Análisis de facturación

# %%
# prompt: Generar codigo para analizar la facturacion total de las 4 tiendas
# Calcular la facturación total por tienda
facturacion_tienda1 = tienda['Precio' ].sum()
facturacion_tienda2 = tienda2['Precio'].sum()
facturacion_tienda3 = tienda3['Precio'].sum()
facturacion_tienda4 = tienda4['Precio'].sum()


# Calcular la facturación total de las 4 tiendas combinadas
facturacion_total_combinada = tiendas_df['Precio'].sum()


print(f"Facturación total Tienda 1: {facturacion_tienda1}")
print(f"Facturación total Tienda 2: {facturacion_tienda2}")
print(f"Facturación total Tienda 3: {facturacion_tienda3}")
print(f"Facturación total Tienda 4: {facturacion_tienda4}")
print(f"Facturación total de las 4 tiendas combinadas: {facturacion_total_combinada}")
# Out:
# Facturación total Tienda 1: 1150880400.0
# Facturación total Tienda 2: 1116343500.0
# Facturación total Tienda 3: 1098019600.0
# Facturación total Tienda 4: 1038375700.0
# Facturación total de las 4 tiendas combinadas: 4403619200.0

# %%
# prompt: generar codigo para analizar de las 4 tiendas, cual tuvo menor facturacion total

# Crear un diccionario para almacenar la facturación por tienda
facturacion_por_tienda = {
    'Tienda 1': facturacion_tienda1,
    'Tienda 2': facturacion_tienda2,
    'Tienda 3': facturacion_tienda3,
    'Tienda 4': facturacion_tienda4
}

# Encontrar la tienda con la menor facturación
tienda_menor_facturacion = min(facturacion_por_tienda, key=facturacion_por_tienda.get)
menor_facturacion = facturacion_por_tienda[tienda_menor_facturacion]

print(f"La tienda con la menor facturación total es: {tienda_menor_facturacion} con una facturación de {menor_facturacion}")

# Encontrar la tienda con la mayor facturación
tienda_mayor_facturacion = max(facturacion_por_tienda, key=facturacion_por_tienda.get)
mayor_facturacion = facturacion_por_tienda[tienda_mayor_facturacion]

print(f"La tienda con la mayor facturación total es: {tienda_mayor_facturacion} con una facturación de {mayor_facturacion}")
# Out:
# La tienda con la menor facturación total es: Tienda 4 con una facturación de 1038375700.0
# La tienda con la mayor facturación total es: Tienda 1 con una facturación de 1150880400.0

# %% [markdown]
# # 2. Ventas por categoría

# %%
# prompt: crear el codigo para determinar cual es la categoría del producto mas vendida en cada tienda

# Para cada tienda, agrupar por 'Categoría' y contar las ventas (o sumar alguna columna que indique venta, como 'Precio')
# Luego, para cada tienda, encontrar la categoría con la mayor suma.

# Función para encontrar la categoría más vendida en una tienda
def categoria_mas_vendida(df, nombre_tienda):
  ventas_por_categoria = df.groupby('Categoría del Producto')['Precio'].sum()
  cantidad_ventas_por_categoria = df.groupby('Categoría del Producto')['Precio'].size()
  if ventas_por_categoria.empty:
    return f"No hay datos de ventas por categoría para {nombre_tienda}"
  categoria_top = cantidad_ventas_por_categoria.idxmax()
  #valor_top = ventas_por_categoria.max()
  valor_top = ventas_por_categoria[categoria_top].sum()
  # Fix: Calculate the number of entries (rows) for the least sold category
  cantidad_top = len(df[df['Categoría del Producto'] == categoria_top])
  return f"La categoría más vendida en {nombre_tienda} es '{categoria_top}' con ventas totales de {valor_top:.2f} con una candidad de {cantidad_top } unidades"


# Aplicar la función a cada tienda
print(categoria_mas_vendida(tienda, 'Tienda 1'))
print(categoria_mas_vendida(tienda2, 'Tienda 2'))
print(categoria_mas_vendida(tienda3, 'Tienda 3'))
print(categoria_mas_vendida(tienda4, 'Tienda 4'))


############################################### Categoria menos vendidas #######################
# Función para encontrar la categoría menos vendida en una tienda
def categoria_menos_vendida(df, nombre_tienda):
  ventas_por_categoria = df.groupby('Categoría del Producto')['Precio'].sum()
  cantidad_ventas_por_categoria = df.groupby('Categoría del Producto')['Precio'].size()
  if ventas_por_categoria.empty:
    return f"No hay datos de ventas por categoría para {nombre_tienda}"
  categoria_up = cantidad_ventas_por_categoria.idxmin()
  #valor_up = ventas_por_categoria.min()
  valor_up = ventas_por_categoria[categoria_up].sum()
  # Fix: Calculate the number of entries (rows) for the least sold category
  cantidad_up = len(df[df['Categoría del Producto'] == categoria_up])
  return f"La categoría menos vendida en {nombre_tienda} es '{categoria_up}' con ventas totales de {valor_up:.2f} con una candidad de {cantidad_up} unidades"
#####################################################################################################

print("\n")
# Aplicar la función a cada tienda
print(categoria_menos_vendida(tienda, 'Tienda 1'))
print(categoria_menos_vendida(tienda2, 'Tienda 2'))
print(categoria_menos_vendida(tienda3, 'Tienda 3'))
print(categoria_menos_vendida(tienda4, 'Tienda 4'))



# Si quieres la categoría más vendida en todas las tiendas combinadas:
ventas_totales_por_categoria = tiendas_df.groupby('Categoría del Producto')['Precio'].sum()
cantidad_ventas_por_categoria = tiendas_df.groupby('Categoría del Producto')['Precio'].size()
if not ventas_totales_por_categoria.empty:
  categoria_top_total = cantidad_ventas_por_categoria.idxmax()
  #valor_top_total = ventas_totales_por_categoria.max()
  valor_top_total =  ventas_totales_por_categoria[categoria_top_total].sum()
    # Fix: Calculate the number of entries (rows) for the least sold category
  cantidad_top_total = len(tiendas_df[tiendas_df['Categoría del Producto'] == categoria_top_total])
  print(f"\nLa categoría más vendida en todas las tiendas combinadas es '{categoria_top_total}' con ventas totales de {valor_top_total:.2f} con una cantidad de {cantidad_top_total} unidades")
else:
  print("\nNo hay datos de ventas por categoría en el conjunto de datos combinado.")

  ################################################################################################################################

# Si quieres la categoría menos vendida en todas las tiendas combinadas:
ventas_totales_por_categoria = tiendas_df.groupby('Categoría del Producto')['Precio'].sum()
cantidad_ventas_por_categoria = tiendas_df.groupby('Categoría del Producto')['Precio'].size()
if not ventas_totales_por_categoria.empty:
  categoria_up_total = cantidad_ventas_por_categoria.idxmin()
  #valor_up_total = ventas_totales_por_categoria.min()
  valor_up_total = ventas_totales_por_categoria[categoria_up_total].sum()

  # Fix: Calculate the number of entries (rows) for the least sold category
  cantidad_up_total = len(tiendas_df[tiendas_df['Categoría del Producto'] == categoria_up_total])
  print(f"La categoría menos vendida en todas las tiendas combinadas es '{categoria_up_total}' con ventas totales de {valor_up_total:.2f} con una cantidad de {cantidad_up_total} unidades")
else:
  print("\nNo hay datos de ventas por categoría en el conjunto de datos combinado.")
# Out:
# La categoría más vendida en Tienda 1 es 'Muebles' con ventas totales de 187633700.00 con una candidad de 465 unidades
# La categoría más vendida en Tienda 2 es 'Muebles' con ventas totales de 176426300.00 con una candidad de 442 unidades
# La categoría más vendida en Tienda 3 es 'Muebles' con ventas totales de 201072100.00 con una candidad de 499 unidades
# La categoría más vendida en Tienda 4 es 'Muebles' con ventas totales de 192528900.00 con una candidad de 480 unidades
#
#
# La categoría menos vendida en Tienda 1 es 'Artículos para el hogar' con ventas totales de 12698400.00 con una candidad de 171 unidades
# La categoría menos vendida en Tienda 2 es 'Artículos para el hogar' con ventas totales de 14746900.00 con una candidad de 181 unidades
# La categoría menos vendida en Tienda 3 es 'Artículos para el hogar' con ventas totales de 15060000.00 con una candidad de 177 unidades
# ...

# %%
# prompt: crear codigo para determinar ventas por cada una de las Categorías del Producto para cada una de las 4 tiendas

# Ventas por categoría para cada tienda
ventas_por_categoria_tienda1 = tienda.groupby('Categoría del Producto')['Precio'].sum().sort_values(ascending=False)
ventas_por_categoria_tienda2 = tienda2.groupby('Categoría del Producto')['Precio'].sum().sort_values(ascending=False)
ventas_por_categoria_tienda3 = tienda3.groupby('Categoría del Producto')['Precio'].sum().sort_values(ascending=False)
ventas_por_categoria_tienda4 = tienda4.groupby('Categoría del Producto')['Precio'].sum().sort_values(ascending=False)


# Para contar la cantidad de ventas por categoría en las 4 tiendas, usa .size() después de groupby
cantidad_por_categoria_tienda1 = tienda.groupby('Categoría del Producto').size()
cantidad_por_categoria_tienda2 = tienda2.groupby('Categoría del Producto').size()
cantidad_por_categoria_tienda3 = tienda3.groupby('Categoría del Producto').size()
cantidad_por_categoria_tienda4 = tienda4.groupby('Categoría del Producto').size()

# prompt: crear codigo para determinar ventas por cada una de las Categorías del Producto para cada una de las 4 tiendas

# Ventas por categoría para cada tienda
ventas_por_categoria_tienda1 = tienda.groupby('Categoría del Producto')['Precio'].sum().sort_values(ascending=False)
ventas_por_categoria_tienda2 = tienda2.groupby('Categoría del Producto')['Precio'].sum().sort_values(ascending=False)
ventas_por_categoria_tienda3 = tienda3.groupby('Categoría del Producto')['Precio'].sum().sort_values(ascending=False)
ventas_por_categoria_tienda4 = tienda4.groupby('Categoría del Producto')['Precio'].sum().sort_values(ascending=False)


# Para contar la cantidad de ventas por categoría en las 4 tiendas, usa .size() después de groupby
cantidad_por_categoria_tienda1 = tienda.groupby('Categoría del Producto').size()
cantidad_por_categoria_tienda2 = tienda2.groupby('Categoría del Producto').size()
cantidad_por_categoria_tienda3 = tienda3.groupby('Categoría del Producto').size()
cantidad_por_categoria_tienda4 = tienda4.groupby('Categoría del Producto').size()


# Impresion de ventas por categoria
print("\nVentas por Categoría del Producto en Tienda 1:\n PRODUCTO \t\t\t  PRECIO")
print(ventas_por_categoria_tienda1)

print("\nVentas por Categoría del Producto en Tienda 2:\n PRODUCTO \t\t\t  PRECIO")
print(ventas_por_categoria_tienda2)

print("\nVentas por Categoría del Producto en Tienda 3:\n PRODUCTO \t\t\t  PRECIO")
print(ventas_por_categoria_tienda3)

print("\nVentas por Categoría del Producto en Tienda 4:\n PRODUCTO \t\t\t  PRECIO")
print(ventas_por_categoria_tienda4)
#print(cuenta_por_categoria_tienda4 )


# Para obtener las ventas por categoría para todas las tiendas combinadas:
ventas_por_categoria_total = tiendas_df.groupby('Categoría del Producto')['Precio'].sum().sort_values(ascending=False)
print("\nVentas totales por Categoría del Producto (Todas las tiendas combinadas):")
ventas_por_categoria_total

print("\n######################################## cantidad de productos vendidos por categoria en las 4 tiendas) ###################")

# Para obtener la cantidad ventas por categoría para las 4 tiendas:

print("\nCantidad de Ventas por Categoría del Producto en Tienda 1:\n PRODUCTO \t\t\t  CANTIDAD")
print(cantidad_por_categoria_tienda1)

print("\nCantidad de Ventas por Categoría del Producto en Tienda 2:\n PRODUCTO \t\t\t  CANTIDAD")
print(cantidad_por_categoria_tienda2)

print("\nCantidad de Ventas por Categoría del Producto en Tienda 3:\n PRODUCTO \t\t\t  CANTIDAD")
print(cantidad_por_categoria_tienda3)

print("\nCantidad de Ventas por Categoría del Producto en Tienda 4:\n PRODUCTO \t\t\t  CANTIDAD")
print(cantidad_por_categoria_tienda4)
#print(cuenta_por_categoria_tienda4 )

cantidad_por_categoria_total = tiendas_df.groupby('Categoría del Producto').size()
print("\ncantidad de Ventas totales por Categoría del Producto (Todas las tiendas combinadas):")
print(cantidad_por_categoria_total)


############################################### analisis ventas por categoria min / max 4 tiendas ::::::::::

# Crear un diccionario para ventas por categoria por tienda
ventas_por_categoria_por_tienda = {
    'Tienda 1': ventas_por_categoria_tienda1,
    'Tienda 2': ventas_por_categoria_tienda2,
    'Tienda 3': ventas_por_categoria_tienda3,
    'Tienda 4': ventas_por_categoria_tienda4
}

# Crear un diccionario para cantidad de ventas por categoria por tienda
cantidad_venta_categoria_por_tienda = {
    'Tienda 1': cantidad_por_categoria_tienda1,
    'Tienda 2': cantidad_por_categoria_tienda2,
    'Tienda 3': cantidad_por_categoria_tienda3,
    'Tienda 4': cantidad_por_categoria_tienda4
}

###################################### salto de linea .... analisis resumido....
print("\n")

#################### analisis de ventas por categoria ::::::::::::::::::::::::::
# Sumar los valores de la Series para obtener el total de ventas por tienda para la comparación
tienda_menor_ventas_por_categoria = min(ventas_por_categoria_por_tienda, key=lambda store: ventas_por_categoria_por_tienda[store].sum())
menor_ventas_por_categoria = ventas_por_categoria_por_tienda[tienda_menor_ventas_por_categoria ].sum()

# Encontrar la tienda con el mayor costo de envio
#tienda_mayor_costo_de_envio1 = max(costo_de_envio_por_tienda, key=costo_de_envio_por_tienda.get)
#mayor_costos_de_envio1 = costo_de_envio_por_tienda[tienda_mayor_costo_de_envio1]
# Sumar los valores de la Series para obtener el total de ventas por tienda para la comparación
tienda_mayor_ventas_por_categoria = max(ventas_por_categoria_por_tienda, key=lambda store: ventas_por_categoria_por_tienda[store].sum())
mayor_ventas_por_categoria= ventas_por_categoria_por_tienda[tienda_mayor_ventas_por_categoria].sum()


print(f"\nLa tienda con la menor ventas por categoria es: {tienda_menor_ventas_por_categoria} con unas ventas totales de  {menor_ventas_por_categoria}")
print(f"\nLa tienda con la mayor ventas por categoria es: {tienda_mayor_ventas_por_categoria} con unas ventas totales de  {mayor_ventas_por_categoria}")
print(f"\n")


############################################################################################################################################################
#################### analisis de cantidad de ventas por categoria::::::::::::::::::::::::::
# Encontrar la tienda con el menor cantidad  de ventas por categoria
tienda_menor_cantidad_de_ventas_categoria = min(cantidad_venta_categoria_por_tienda, key=lambda store: cantidad_venta_categoria_por_tienda[store].sum())
menor_cantidad_de_ventas_categoria = cantidad_venta_categoria_por_tienda[tienda_menor_cantidad_de_ventas_categoria].sum()
# Encontrar la tienda con la mayor cantidad de ventas por categoria
tienda_mayor_cantidad_de_ventas_categoria = max(cantidad_venta_categoria_por_tienda, key=lambda store: cantidad_venta_categoria_por_tienda[store].sum())
mayor_cantidad_de_venta_categoria = cantidad_venta_categoria_por_tienda[tienda_mayor_cantidad_de_ventas_categoria].sum()


print(f"\nLa tienda con la menor cantidad ventas por categoria es: {tienda_menor_cantidad_de_ventas_categoria} con una cantidad ventas totales de  {menor_cantidad_de_ventas_categoria}")
print(f"\nLa tienda con la mayor cantidad ventas por categoria es: {tienda_mayor_cantidad_de_ventas_categoria} con una cantidad ventas totales de  {mayor_cantidad_de_venta_categoria}")
# Out:
# Ventas por Categoría del Producto en Tienda 1:
#  PRODUCTO 			  PRECIO
# Categoría del Producto
# Electrónicos               429493500.0
# Electrodomésticos          363685200.0
# Muebles                    187633700.0
# Instrumentos musicales      91299000.0
# Deportes y diversión        39290000.0
# Juguetes                    17995700.0
# Artículos para el hogar     12698400.0
# Libros                       8784900.0
# Name: Precio, dtype: float64
#
# Ventas por Categoría del Producto en Tienda 2:
#  PRODUCTO 			  PRECIO
# Categoría del Producto
# Electrónicos               410831100.0
# Electrodomésticos          348567800.0
# Muebles                    176426300.0
# Instrumentos musicales     104990300.0
# Deportes y diversión        34744500.0
# Juguetes                    15945400.0
# Artículos para el hogar     14746900.0
# Libros                      10091200.0
# Name: Precio, dtype: float64
#
# Ventas por Categoría del Producto en Tienda 3:
#  PRODUCTO 			  PRECIO
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
# prompt: crear un codigo que analice cual es el promedio de clasificacion de los clientes en las 4 tiendas
import pandas as pd
# definiendo tiendas
url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Concatenar los dataframes de las tiendas
tiendas_df = pd.concat([tienda, tienda2, tienda3, tienda4])

# Imprimir los nombres de las columnas para verificar el nombre correcto de la columna de clasificación
# print("Columnas disponibles en el DataFrame concatenado:")
# print(tiendas_df.columns)

# Reemplaza 'NombreDeLaColumnaCorrecto' con el nombre exacto de la columna de clasificación que encuentres en el output anterior.
# Por ejemplo, si la columna se llama 'Rating', cambia 'NombreDeLaColumnaCorrecto' a 'Rating'.
# Si la columna se llama 'Calificacion_Cliente', cambia 'NombreDeLaColumnaCorrecto' a 'Calificacion_Cliente'.
try:
    # Intenta usar el nombre de columna que crees que es el correcto.
    # Si el print de columnas te muestra un nombre diferente, úsalo aquí.
    promedio_clasificacion = tiendas_df['Calificación'].mean() # Asumiendo que la columna se llama 'Calificación' (sin mayúscula inicial en la base de datos)
    promedio_clasificacion_tienda1 = tienda['Calificación'].mean() # Asumiendo que la columna se llama 'Calificación' (sin mayúscula inicial en la base de datos)
    promedio_clasificacion_tienda2 = tienda2['Calificación'].mean() # Asumiendo que la columna se llama 'Calificación' (sin mayúscula inicial en la base de datos)
    promedio_clasificacion_tienda3 = tienda3['Calificación'].mean() # Asumiendo que la columna se llama 'Calificación' (sin mayúscula inicial en la base de datos)
    promedio_clasificacion_tienda4 = tienda4['Calificación'].mean()
except KeyError:
    # Si 'Calificación' tampoco funciona, puedes probar con otros nombres comunes o referirte al output de tiendas_df.columns
    # print("La columna 'Calificación' no fue encontrada. Por favor, verifica el nombre correcto de la columna en el output de tiendas_df.columns")
    # Por ahora, puedes intentar con 'clasificacion' si crees que podría ser ese el nombre
    try:
        promedio_clasificacion = tiendas_df['clasificacion'].mean()
        promedio_clasificacion_tienda1 = tienda['Calificación'].mean()
        promedio_clasificacion_tienda2 = tienda2['Calificación'].mean()
        promedio_clasificacion_tienda3 = tienda3['Calificación'].mean()
        promedio_clasificacion_tienda4 = tienda4['Calificación'].mean()
    except KeyError:
        print("No se encontró una columna de clasificación común. Por favor, examine el output de tiendas_df.columns y actualice el código con el nombre correcto.")
        promedio_clasificacion = None # O manejar el error de otra forma

if promedio_clasificacion is not None:
    print(f"El promedio de clasificación de los clientes en la tienda 1 es: {promedio_clasificacion_tienda1}")
    print(f"El promedio de clasificación de los clientes en la tienda 2 es: {promedio_clasificacion_tienda2}")
    print(f"El promedio de clasificación de los clientes en la tienda 3 es: {promedio_clasificacion_tienda3}")
    print(f"El promedio de clasificación de los clientes en la tienda 4 es: {promedio_clasificacion_tienda4}")
    print(f"\n")
    print(f"El promedio de clasificación de los clientes en las 4 tiendas es: {promedio_clasificacion}")

############################################### Menor y Mayor Clasificacion de Tienda::::::::::

# Crear un diccionario para Clasificacion por tienda
Clasificacion_Promedio_Por_tienda= {
    'Tienda 1': promedio_clasificacion_tienda1 ,
    'Tienda 2': promedio_clasificacion_tienda2,
    'Tienda 3': promedio_clasificacion_tienda3,
    'Tienda 4': promedio_clasificacion_tienda4
}

###################################### salto de linea .... analisis resumido....
print("\n")

#################### analisis de clasificacion por tienda::::::::::::::::::::::::::
# Encontrar la tienda con el menor clasificacion
tienda_menor_clasificacion = min(Clasificacion_Promedio_Por_tienda, key=Clasificacion_Promedio_Por_tienda.get)
menor_clasificacion = Clasificacion_Promedio_Por_tienda[tienda_menor_clasificacion]

# Encontrar la tienda con el mayor costo de envio
tienda_mayor_clasificacion= max(Clasificacion_Promedio_Por_tienda, key=Clasificacion_Promedio_Por_tienda.get)
mayor_clasificacion = Clasificacion_Promedio_Por_tienda[tienda_mayor_clasificacion]


print(f"La tienda con el menor promedio de clasificacion es: {tienda_menor_clasificacion} con  {menor_clasificacion}")
print(f"La tienda con el mayor promedio de clasificacion es: {tienda_mayor_clasificacion} con  {mayor_clasificacion}")
# Out:
# El promedio de clasificación de los clientes en la tienda 1 es: 3.976685036032217
# El promedio de clasificación de los clientes en la tienda 2 es: 4.037303942348453
# El promedio de clasificación de los clientes en la tienda 3 es: 4.048325561678677
# El promedio de clasificación de los clientes en la tienda 4 es: 3.9957591178965224
#
#
# El promedio de clasificación de los clientes en las 4 tiendas es: 4.014520402755696
#
#
# La tienda con el menor promedio de clasificacion es: Tienda 1 con  3.976685036032217
# La tienda con el mayor promedio de clasificacion es: Tienda 3 con  4.048325561678677

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
# prompt: crear codigo para determinar producto más y menos vendido para cada una de las 4 tiendas

import pandas as pd

# definiendo tiendas
url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Concatenar los dataframes de las tiendas
tiendas_df = pd.concat([tienda, tienda2, tienda3, tienda4])

# Ventas por producto para cada tienda
ventas_por_producto_tienda1 = tienda.groupby('Producto')['Precio'].sum().sort_values(ascending=False)
ventas_por_producto_tienda2 = tienda2.groupby('Producto')['Precio'].sum().sort_values(ascending=False)
ventas_por_producto_tienda3 = tienda3.groupby('Producto')['Precio'].sum().sort_values(ascending=False)
ventas_por_producto_tienda4 = tienda4.groupby('Producto')['Precio'].sum().sort_values(ascending=False)

# Cantidad de Ventas por producto para cada tienda
cantidad_ventas_por_producto_tienda1 = tienda.groupby('Producto')['Precio'].size().sort_values(ascending=False)
cantidad_ventas_por_producto_tienda2 = tienda2.groupby('Producto')['Precio'].size().sort_values(ascending=False)
cantidad_ventas_por_producto_tienda3 = tienda3.groupby('Producto')['Precio'].size().sort_values(ascending=False)
cantidad_ventas_por_producto_tienda4 = tienda4.groupby('Producto')['Precio'].size().sort_values(ascending=False)


# Impresion ventas  por producto
print("\nVentas por Categoría del Producto en Tienda 1:\n PRODUCTO \t\t\t  PRECIO")
print(ventas_por_producto_tienda1)

print("\nVentas por Categoría del Producto en Tienda 2:\n PRODUCTO \t\t\t  PRECIO")
print(ventas_por_producto_tienda2)

print("\nVentas por Categoría del Producto en Tienda 3:\n PRODUCTO \t\t\t  PRECIO")
print(ventas_por_producto_tienda3)

print("\nVentas por Categoría del Producto en Tienda 4:\n PRODUCTO \t\t\t  PRECIO")
print(ventas_por_producto_tienda4)
#print(cuenta_por_categoria_tienda4 )

# Para obtener las ventas por producto para todas las tiendas combinadas:
ventas_por_producto_total = tiendas_df.groupby('Producto')['Precio'].sum().sort_values(ascending=False)
print("\nVentas totales por Producto (Todas las tiendas combinadas):")
ventas_por_producto_total

print("\n######################################## cantidad de productos vendidos por categoria en las 4 tiendas) ###################")

# Para obtener la cantidad ventas por categoría para las 4 tiendas:

print("\nCantidad de Ventas por Producto en Tienda 1:\n PRODUCTO \t\t\t  CANTIDAD")
print(cantidad_ventas_por_producto_tienda1 )

print("\nCantidad de Ventas por Producto en Tienda 2:\n PRODUCTO \t\t\t  CANTIDAD")
print(cantidad_ventas_por_producto_tienda2)

print("\nCantidad de Ventas por Producto en Tienda 3:\n PRODUCTO \t\t\t  CANTIDAD")
print(cantidad_ventas_por_producto_tienda3)

print("\nCantidad de Ventas por Producto en Tienda 4:\n PRODUCTO \t\t\t  CANTIDAD")
print(cantidad_ventas_por_producto_tienda4)
#print(cuenta_por_categoria_tienda4 )

cantidad_por_producto_total = tiendas_df.groupby('Producto')['Precio'].size().sort_values(ascending=False)
print("\ncantidad de Productos Vendidos en Todas las Tiendas (Todas las tiendas combinadas):")
print(cantidad_por_producto_total)
# Out:
# Ventas por Categoría del Producto en Tienda 1:
#  PRODUCTO 			  PRECIO
# Producto
# TV LED UHD 4K                  142150200.0
# Refrigerador                   112143300.0
# Iphone 15                       97902200.0
# Smart TV                        67452100.0
# Lavadora de ropa                65783600.0
# Lavavajillas                    62054900.0
# Secadora de ropa                59062400.0
# Tablet ABXY                     47639800.0
# Batería                         37693900.0
# Guitarra eléctrica              37292200.0
# Microondas                      34761500.0
# Celular ABXY                    32651000.0
# Sofá reclinable                 31379400.0
# Cama king                       31176600.0
# Estufa                          29879500.0
# Armario                         29462300.0
# Bicicleta                       27444600.0
# Cama box                        22094700.0
# Silla de oficina                17667300.0
# Impresora                       16413300.0
# ...

# %%
############################################## analisis ventas por producto min / max 4 tiendas ::::::::::


# prompt: crear codigo para determinar producto más y menos vendido para cada una de las 4 tiendas

# Ventas por producto para cada tienda
ventas_por_producto_tienda1 = tienda.groupby('Producto')['Precio'].sum().sort_values(ascending=False)
ventas_por_producto_tienda2 = tienda2.groupby('Producto')['Precio'].sum().sort_values(ascending=False)
ventas_por_producto_tienda3 = tienda3.groupby('Producto')['Precio'].sum().sort_values(ascending=False)
ventas_por_producto_tienda4 = tienda4.groupby('Producto')['Precio'].sum().sort_values(ascending=False)

# Cantidad de Ventas por producto para cada tienda
cantidad_ventas_por_producto_tienda1 = tienda.groupby('Producto')['Precio'].size().sort_values(ascending=False)
cantidad_ventas_por_producto_tienda2 = tienda2.groupby('Producto')['Precio'].size().sort_values(ascending=False)
cantidad_ventas_por_producto_tienda3 = tienda3.groupby('Producto')['Precio'].size().sort_values(ascending=False)
cantidad_ventas_por_producto_tienda4 = tienda4.groupby('Producto')['Precio'].size().sort_values(ascending=False)

# Crear un diccionario para ventas por producto por tienda
ventas_por_producto_por_tienda = {
    'Tienda 1': ventas_por_producto_tienda1,
    'Tienda 2': ventas_por_producto_tienda2,
    'Tienda 3': ventas_por_producto_tienda3,
    'Tienda 4': ventas_por_producto_tienda4
}

# Crear un diccionario para cantidad de ventas por producto por tienda
cantidad_venta_producto_por_tienda = {
    'Tienda 1': cantidad_ventas_por_producto_tienda1,
    'Tienda 2': cantidad_ventas_por_producto_tienda2,
    'Tienda 3': cantidad_ventas_por_producto_tienda3,
    'Tienda 4': cantidad_ventas_por_producto_tienda4
}

############################################################################################################################################

###################################### salto de linea .... analisis resumido....
print("\n")

# Función para encontrar el producto más vendida en una tienda
def producto_mas_vendida(df, nombre_tienda):
  ventas_por_producto = df.groupby('Producto')['Precio'].sum()
  if ventas_por_producto.empty:
    return f"No hay datos de ventas por producto para {nombre_tienda}"
  producto_top = ventas_por_producto.idxmax()
  valor_top = ventas_por_producto.max()
  # Fix: Calculate the number of entries (rows) for the least sold category
  cantidad_top = len(df[df['Producto'] == producto_top])
  return f"El producto más vendida en {nombre_tienda} es '{producto_top}' con ventas totales de {valor_top:.2f} con una candidad de {cantidad_top } unidades"


# Aplicar la función a cada tienda
print(producto_mas_vendida(tienda, 'Tienda_1'))
print(producto_mas_vendida(tienda2, 'Tienda_2'))
print(producto_mas_vendida(tienda3, 'Tienda_3'))
print(producto_mas_vendida(tienda4, 'Tienda_4'))

#####################################################################################################################################################################

############################################### Categoria menos vendidas #######################
# Función para encontrar el producto menos vendido en una tienda
def producto_menos_vendida(df, nombre_tienda):
  ventas_por_producto = df.groupby('Producto')['Precio'].sum()
  if ventas_por_producto.empty:
    return f"No hay datos de ventas por producto para {nombre_tienda}"
  producto_up = ventas_por_producto.idxmin()
  valor_up = ventas_por_producto.min()
  # Fix: Calculate the number of entries (rows) for the least sold category
  cantidad_up = len(df[df['Producto'] == producto_up])
  return f"El producto menos vendida en {nombre_tienda} es '{producto_up}' con ventas totales de {valor_up:.2f} con una candidad de {cantidad_up} unidades"
#####################################################################################################

print("\n")
# Aplicar la función a cada tienda
print(producto_menos_vendida(tienda, 'Tienda_1'))
print(producto_menos_vendida(tienda2, 'Tienda_2'))
print(producto_menos_vendida(tienda3, 'Tienda_3'))
print(producto_menos_vendida(tienda4, 'Tienda_4'))


############################################### en todas las 4 tiendas, producto mas y menos vendido ---------------------------------
# Si quieres el producto más vendida en todas las tiendas combinadas:
ventas_totales_por_producto = tiendas_df.groupby('Producto')['Precio'].sum()
if not ventas_totales_por_producto.empty:
  producto_top_total = ventas_totales_por_producto.idxmax()
  valor_top_total = ventas_totales_por_producto.max()
    # Fix: Calculate the number of entries (rows) for the least sold category
  cantidad_top_total = len(tiendas_df[tiendas_df['Producto'] == producto_top_total])
  print(f"\nEl producto más vendida en todas las tiendas combinadas es '{producto_top_total}' con ventas totales de {valor_top_total:.2f} con una cantidad de {cantidad_top_total} unidades")
else:
  print("\nNo hay datos de ventas por categoría en el conjunto de datos combinado.")

  ################################################################################################################################

# Si quieres el producto menos vendida en todas las tiendas combinadas:
ventas_totales_por_producto = tiendas_df.groupby('Producto')['Precio'].sum()
if not ventas_totales_por_producto.empty:
  producto_up_total = ventas_totales_por_producto.idxmin()
  valor_up_total = ventas_totales_por_producto.min()

  # Fix: Calculate the number of entries (rows) for the least sold category
  cantidad_up_total = len(tiendas_df[tiendas_df['Producto'] == producto_up_total])
  print(f"El producto menos vendida en todas las tiendas combinadas es '{producto_up_total}' con ventas totales de {valor_up_total:.2f} con una cantidad de {cantidad_up_total} unidades")
else:
  print("\nNo hay datos de ventas por categoría en el conjunto de datos combinado.")

################################################### ANALISIS TERMINADO ##############################################################################################

#################### analisis de ventas por producto / menor ::::::::::::::::::::::::::
# Sumar los valores de la Series para obtener el total de ventas por producto en tienda para la comparación
tienda_menor_ventas_por_producto = min(ventas_por_producto_por_tienda, key=lambda store: ventas_por_producto_por_tienda[store].sum())
menor_ventas_por_producto = ventas_por_producto_por_tienda[tienda_menor_ventas_por_producto].sum()

######################### anlisis cantidad de ventas por producto ........................
# Sumar los valores de la Series para obtener el total de ventas por producto en tienda para la comparación
tienda_menor_cantidad_por_producto = min(cantidad_venta_producto_por_tienda, key=lambda store: cantidad_venta_producto_por_tienda[store].sum())
menor_cantidad_por_producto = cantidad_venta_producto_por_tienda[tienda_menor_cantidad_por_producto].sum()

#################### analisis de ventas por producto / mayor ::::::::::::::::::::::::::

# Sumar los valores de la Series para obtener el total de ventas por producto en cada tienda para la comparación
tienda_mayor_ventas_por_producto = max(ventas_por_producto_por_tienda, key=lambda store: ventas_por_producto_por_tienda[store].sum())
mayor_ventas_por_producto= ventas_por_producto_por_tienda[tienda_mayor_ventas_por_producto].sum()


######################### anlisis cantidad de ventas por producto ........................
# Sumar los valores de la Series para obtener el total de cantidad por producto en cada tienda para la comparación
tienda_mayor_cantidad_por_producto = max(cantidad_venta_producto_por_tienda, key=lambda store: cantidad_venta_producto_por_tienda[store].sum())
mayor_cantidad_por_producto= cantidad_venta_producto_por_tienda[tienda_mayor_cantidad_por_producto].sum()

########################### impresiones ....................................................
print(f"\n")
print(f"La tienda con la menor  ventas por producto es: {tienda_menor_ventas_por_producto} con una cantidad ventas totales de  {menor_ventas_por_producto}")
print(f"La tienda con la mayor  ventas por producto es: {tienda_mayor_ventas_por_producto} con una cantidad ventas totales de  {mayor_ventas_por_producto}")
print(f"\n")
print(f"La tienda con la menor cantidad ventas por producto es: {tienda_menor_cantidad_por_producto} con una cantidad ventas totales de  {menor_cantidad_por_producto}")
print(f"La tienda con la mayor cantidad ventas por producto es: {tienda_mayor_cantidad_por_producto} con una cantidad ventas totales de  {mayor_cantidad_por_producto}")
# Out:
# El producto más vendida en Tienda_1 es 'TV LED UHD 4K' con ventas totales de 142150200.00 con una candidad de 60 unidades
# El producto más vendida en Tienda_2 es 'Iphone 15' con ventas totales de 113225800.00 con una candidad de 55 unidades
# El producto más vendida en Tienda_3 es 'Refrigerador' con ventas totales de 99889700.00 con una candidad de 50 unidades
# El producto más vendida en Tienda_4 es 'Iphone 15' con ventas totales de 96697500.00 con una candidad de 48 unidades
#
#
# El producto menos vendida en Tienda_1 es 'Cuerda para saltar' con ventas totales de 652800.00 con una candidad de 40 unidades
# El producto menos vendida en Tienda_2 es 'Cubo mágico 8x8' con ventas totales de 643600.00 con una candidad de 45 unidades
# El producto menos vendida en Tienda_3 es 'Cubo mágico 8x8' con ventas totales de 640400.00 con una candidad de 44 unidades
# El producto menos vendida en Tienda_4 es 'Cuerda para saltar' con ventas totales de 704800.00 con una candidad de 43 unidades
#
# ...

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tiendas_df = pd.concat([tienda, tienda2, tienda3, tienda4])

# Imprimir los nombres de las columnas para verificar el nombre correcto de la columna de costo de envío
# print("Columnas disponibles en el DataFrame concatenado:")
# print(tiendas_df.columns)

# Reemplaza 'NombreDeLaColumnaCorrecto' con el nombre exacto de la columna de costo de envío que encuentres en el output anterior.
# Por ejemplo, si la columna se llama 'Rating', cambia 'NombreDeLaColumnaCorrecto' a 'Rating'.
# Si la columna se llama 'Calificacion_Cliente', cambia 'NombreDeLaColumnaCorrecto' a 'Calificacion_Cliente'.
try:
    # Intenta usar el nombre de columna que crees que es el correcto.
    # Si el print de columnas te muestra un nombre diferente, úsalo aquí.
    promedio_costo_de_envío = tiendas_df['Costo de envío'].mean() # Asumiendo que la columna se llama 'Costo de envío' (sin mayúscula inicial en la base de datos)
except KeyError:
    # Si 'Costo de envío' tampoco funciona, puedes probar con otros nombres comunes o referirte al output de tiendas_df.columns
    # print("La columna 'Costo de envío' no fue encontrada. Por favor, verifica el nombre correcto de la columna en el output de tiendas_df.columns")
    # Por ahora, puedes intentar con 'costo de envío' si crees que podría ser ese el nombre
    try:
         promedio_costo_de_envío = tiendas_df['Costo de envío'].mean()
    except KeyError:
        print("No se encontró una columna de Costo de envío. Por favor, examine el output de tiendas_df.columns y actualice el código con el nombre correcto.")
        promedio_costo_de_envío = None # O manejar el error de otra forma

if promedio_costo_de_envío is not None:
    print(f"El promedio de Costo de envío en las 4 tiendas es: {promedio_costo_de_envío}")
# Out:
# El promedio de Costo de envío en las 4 tiendas es: 24875.145733969264

# %%
# prompt: Generar codigo para analizar los costo de envio total de las 4 tiendas
############################################################### suma total
# Calcular la facturación total por tienda
total_costo_de_envío_tienda1 = tienda['Costo de envío' ].sum()
total_costo_de_envío_tienda2 = tienda2['Costo de envío'].sum()
total_costo_de_envío_tienda3 = tienda3['Costo de envío'].sum()
total_costo_de_envío_tienda4 = tienda4['Costo de envío'].sum()

# Calcular el costo de envio total de las 4 tiendas combinadas
total_costo_de_envío_total_combinada = tiendas_df['Costo de envío'].sum()
###################################################################### cuenta / cantidad total
# Calcular cantidad total de envios por tienda
total_envío_tienda1 = len(tienda['Costo de envío'])
total_envío_tienda2 = len(tienda2['Costo de envío'])
total_envío_tienda3 = len(tienda3['Costo de envío'])
total_envío_tienda4 = len(tienda4['Costo de envío'])

# Calcular cantidad total de envio total de las 4 tiendas combinadas
total_envío_combinada = len(tiendas_df['Costo de envío'])

####################################################### promedio

# Calcular promedio total de envios por tienda
promedio_costo_envío_tienda1 = total_costo_de_envío_tienda1 / total_envío_tienda1
promedio_costo_envío_tienda2 = total_costo_de_envío_tienda2 / total_envío_tienda2
promedio_costo_envío_tienda3 = total_costo_de_envío_tienda3 / total_envío_tienda3
promedio_costo_envío_tienda4 = total_costo_de_envío_tienda4 / total_envío_tienda4

# Calcular promedio total de costo de envio total de las 4 tiendas combinadas
total_promedio_costo_envío_combinada = tiendas_df['Costo de envío'].mean()

###################### impresiones.................................

print(f"\nEl Costo Total de Envio para  Tienda 1: {total_costo_de_envío_tienda1} con una cantidad total de envios de {total_envío_tienda1} para un promedio total de {promedio_costo_envío_tienda1}")
print(f"\nEl Costo Total de Envio para  Tienda 2: {total_costo_de_envío_tienda2} con una cantidad total de envios de {total_envío_tienda2} para un promedio total de {promedio_costo_envío_tienda2}")
print(f"\nEl Costo Total de Envio para  Tienda 3: {total_costo_de_envío_tienda3} con una cantidad total de envios de {total_envío_tienda3} para un promedio total de {promedio_costo_envío_tienda3}")
print(f"\nEl Costo Total de Envio para  Tienda 4: {total_costo_de_envío_tienda4} con una cantidad total de envios de {total_envío_tienda4} para un promedio total de {promedio_costo_envío_tienda4}")
print(f"\nEl Costo Total de Envio para las 4 tiendas es: {total_costo_de_envío_total_combinada} con una cantidad total de envios de {total_envío_combinada} para un promedio total de {total_promedio_costo_envío_combinada}")

############################################### menor costo de envio y envios::::::::::

# Crear un diccionario para costo de envio por tienda
costo_de_envio_por_tienda = {
    'Tienda 1': total_costo_de_envío_tienda1,
    'Tienda 2': total_costo_de_envío_tienda2,
    'Tienda 3': total_costo_de_envío_tienda3,
    'Tienda 4': total_costo_de_envío_tienda4
}

# Crear un diccionario para cantidad de envio por tienda
envio_por_tienda = {
    'Tienda 1': total_envío_tienda1,
    'Tienda 2': total_envío_tienda2,
    'Tienda 3': total_envío_tienda3,
    'Tienda 4': total_envío_tienda4
}



###################################### salto de linea .... analisis resumido....
print("\n")

#################### analisis de costos de envio::::::::::::::::::::::::::
# Encontrar la tienda con el menor costo de envio
tienda_menor_costo_de_envio = min(costo_de_envio_por_tienda, key=costo_de_envio_por_tienda.get)
menor_costos_de_envio = costo_de_envio_por_tienda[tienda_menor_costo_de_envio]

# Encontrar la tienda con el mayor costo de envio
tienda_mayor_costo_de_envio1 = max(costo_de_envio_por_tienda, key=costo_de_envio_por_tienda.get)
mayor_costos_de_envio1 = costo_de_envio_por_tienda[tienda_mayor_costo_de_envio1]

#################### analisis de envios::::::::::::::::::::::::::
# Encontrar la tienda con el menor cantidad  de envios
tienda_menor_cantidad_de_envio = min(envio_por_tienda, key=envio_por_tienda.get)
menor_cantidad_de_envio = envio_por_tienda[tienda_menor_cantidad_de_envio]

# Encontrar la tienda con la mayor cantidad de envios
tienda_mayor_cantidad_de_envio1 = max(envio_por_tienda, key=envio_por_tienda.get)
mayor_cantidad_de_envio1 = envio_por_tienda[tienda_mayor_cantidad_de_envio1]

print(f"\nLa tienda con la menor costo de envio total es: {tienda_menor_costo_de_envio} con un costo de envio de {menor_costos_de_envio}")
print(f"\nLa tienda con el mayor costo de envio total es: {tienda_mayor_costo_de_envio1} con un costo de envio de {mayor_costos_de_envio1}")
print(f"\n")
print(f"\nLa tienda con la menor envios total es: {tienda_menor_cantidad_de_envio} con un cantidad de {menor_cantidad_de_envio}")
print(f"\nLa tienda con el mayor envios total es: {tienda_mayor_cantidad_de_envio1} con un cantidad de {mayor_cantidad_de_envio1}")
# Out:
# El Costo Total de Envio para  Tienda 1: 61377900.0 con una cantidad total de envios de 2359 para un promedio total de 26018.60958033065
#
# El Costo Total de Envio para  Tienda 2: 59485100.0 con una cantidad total de envios de 2359 para un promedio total de 25216.235693090293
#
# El Costo Total de Envio para  Tienda 3: 58516600.0 con una cantidad total de envios de 2359 para un promedio total de 24805.680373039424
#
# El Costo Total de Envio para  Tienda 4: 55317400.0 con una cantidad total de envios de 2358 para un promedio total de 23459.457167090754
#
# El Costo Total de Envio para las 4 tiendas es: 234697000.0 con una cantidad total de envios de 9435 para un promedio total de 24875.145733969264
#
#
#
# La tienda con la menor costo de envio total es: Tienda 4 con un costo de envio de 55317400.0
#
# La tienda con el mayor costo de envio total es: Tienda 1 con un costo de envio de 61377900.0
#
#
#
# La tienda con la menor envios total es: Tienda 4 con un cantidad de 2358
#
# ...

# %% [markdown]
# Analisis de Datos 4 Tiendas:
#
#
#
# > Agregar bloque entrecomillado
# **FACTURACION  / TIENDAS**
#
# * Facturación total Tienda 1: 1150880400.0
# * Facturación total Tienda 2: 1116343500.0
# * Facturación total Tienda 3: 1098019600.0
# * Facturación total Tienda 4: 1038375700.0
# * Facturación total de las 4 tiendas combinadas: 4403619200.0
#
# **ANALISIS GLOBAL DE LAS 4 TIENDAS**: TIENDA CON MAYOR Y MENOR FACTURACIÓN:
# * La tienda con la menor facturación total es: Tienda 4 con una facturación de 1038375700.0
# * La tienda con la mayor facturación total es: Tienda 1 con una facturación de 1150880400.0

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de facturación (ejemplo, reemplaza con tus datos reales)
facturacion_tienda1 = 1150880400.0
facturacion_tienda2 = 1116343500.0
facturacion_tienda3 = 1098019600.0
facturacion_tienda4 = 1038375700.0
facturacion_total_combinada = 4403619200.0

# Nombres de las tiendas
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4', 'Tienda _combinada']

# Valores de facturación
valores = [facturacion_tienda1, facturacion_tienda2, facturacion_tienda3, facturacion_tienda4,facturacion_total_combinada]

# Crear el gráfico de barras
plt.figure(figsize=(8, 6))
plt.bar(tiendas, valores, color=['skyblue', 'lightgreen', 'salmon', 'gold'])

# Añadir títulos y etiquetas
plt.title('Facturación por Tienda')
plt.xlabel('Tiendas')
plt.ylabel('Facturación ($)')
plt.ylim(0, max(valores) * 1.1) # Ajustar el límite del eje y para mejor visualización

# Mostrar el valor en la parte superior de cada barra
for i, v in enumerate(valores):
    plt.text(i, v + 500, str(v), ha='center', va='bottom')

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %%
############################ Tienda con Mayor Facturación ##########################

import matplotlib.pyplot as plt
import numpy as np

# Datos de facturación (ejemplo, reemplaza con tus datos reales)
facturacion_mayor_facturación = 1150880400.0
facturacion_menor_facturación = 1038375700.0


# Nombres de las tiendas
tiendas = ['Tienda 1', 'Tienda 4']

# Valores de facturación
valores = [facturacion_mayor_facturación, facturacion_menor_facturación]

# Crear el gráfico de barras
plt.figure(figsize=(8, 6))
plt.bar(tiendas, valores, color=['skyblue', 'lightgreen', 'salmon', 'gold'])

# Añadir títulos y etiquetas
plt.title('Facturación por Tienda')
plt.xlabel('Tiendas')
plt.ylabel('Facturación ($)')
plt.ylim(0, max(valores) * 1.1) # Ajustar el límite del eje y para mejor visualización

# Mostrar el valor en la parte superior de cada barra
for i, v in enumerate(valores):
    plt.text(i, v + 500, str(v), ha='center', va='bottom')

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %% [markdown]
# **VENTAS POR CATEGORIA**
# La categoría más vendida
# * en Tienda 1 es 'Muebles' con ventas totales de 187633700.00 con una candidad de 465 unidades
# * La categoría más vendida en Tienda 2 es 'Muebles' con ventas totales de 176426300.00 con una candidad de 442 unidades
# * La categoría más vendida en Tienda 3 es 'Muebles' con ventas totales de 201072100.00 con una candidad de 499 unidades
# * La categoría más vendida en Tienda 4 es 'Muebles' con ventas totales de 192528900.00 con una candidad de 480 unidades
#
#
# La categoría menos vendida
# * en Tienda 1 es 'Artículos para el hogar' con ventas totales de 12698400.00 con una candidad de 171 unidades
# * La categoría menos vendida en Tienda 2 es 'Artículos para el hogar' con ventas totales de 14746900.00 con una candidad de 181 unidades
# * La categoría menos vendida en Tienda 3 es 'Artículos para el hogar' con ventas totales de 15060000.00 con una candidad de 177 unidades
# * La categoría menos vendida en Tienda 4 es 'Instrumentos musicales' con ventas totales de 75102400.00 con una candidad de 170 unidades
#
# * La categoría más vendida en todas las tiendas combinadas es '**Muebles**' con **ventas totales de 757661000.00** con una cantidad de **1886 unidades**.
# * La categoría **menos vendida** en todas las tiendas combinadas es '**Artículos para el hogar**' con ventas totales de **57579800.00** con una cantidad de **730 unidades**.
#
#
# ### **Analisis Resumido**
#
# * La tienda con la **menor ventas por categoria** es: **Tienda 4** con unas ventas totales de ** 1038375700.0**.
# * La tienda con la** mayor ventas por categoria** es: **Tienda 1** con unas ventas totales de ** 1150880400.0**.
#
#
# * La tienda con la **menor cantidad ventas** por categoria es: **Tienda 4** con una cantidad ventas totales de  **2358**
# * La tienda con la **mayor cantidad ventas** por categoria es:** Tienda 1** con una cantidad ventas totales de  **2359**

# %%
import matplotlib.pyplot as plt

categorias = ['Tienda 4', 'Tienda 1']
ventas_totales = [1038375700.0, 1150880400.0]

plt.figure(figsize=(8, 8))
plt.pie(ventas_totales, labels=categorias, autopct='%1.1f%%', startangle=140)
plt.title('Distribución de Ventas Totales por Categoría En Tienda')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
import matplotlib.pyplot as plt

categorias = ['Tienda 4 : 2358 unidades', 'Tienda 1: 2359 unidades']
Cantidades_totales = [2358, 2359]

plt.figure(figsize=(8, 8))
plt.pie(Cantidades_totales, labels=categorias, autopct='%1.1f%%', startangle=140)
plt.title('Distribución de Cantidad Ventas Totales En Categoría')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
import matplotlib.pyplot as plt

categorias = ['Muebles', 'Artículos para el Hogar']
ventas_totales = [757661000.00, 57579800.00]

plt.figure(figsize=(8, 8))
plt.pie(ventas_totales, labels=categorias, autopct='%1.1f%%', startangle=140)
plt.title('Distribución de Ventas Totales por Categoría')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data = {
    'Tienda 1': {'categoria_mas_vendida': 'Muebles', 'ventas_totales': 187633700.00, 'cantidad': 465},
    'Tienda 2': {'categoria_mas_vendida': 'Muebles', 'ventas_totales': 176426300.00, 'cantidad': 442},
    'Tienda 3': {'categoria_mas_vendida': 'Muebles', 'ventas_totales': 201072100.00, 'cantidad': 499},
    'Tienda 4': {'categoria_mas_vendida': 'Muebles', 'ventas_totales': 192528900.00, 'cantidad': 480}
}

tiendas = list(data.keys())
cantidades = [data[tienda]['cantidad'] for tienda in tiendas]

# Nombres de las tiendas
#tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4' ]


# Valores de facturación
#valores = [data['Tienda 1'], data['Tienda 2'], data['Tienda 3'], data['Tienda 4']]

plt.figure(figsize=(8, 6))
plt.bar(tiendas, cantidades, color='skyblue')
plt.xlabel('Tiendas')
plt.ylabel('Cantidad de Unidades Vendidas')
plt.title('Cantidad de Unidades Vendidas por Tienda (Categoría: Muebles) / Mayor Categoria Vendida')
# Mostrar el valor en la parte superior de cada barra para el primer plot
for i, v in enumerate(cantidades):
    plt.text(i, v + 10, str(v), ha='center', va='bottom')
plt.show()

########################################### por Valor Total ###################################333

#tiendas = list(data.keys())
cantidades_valores = [data[tienda]['ventas_totales'] for tienda in tiendas]



plt.figure(figsize=(8, 6))
plt.bar(tiendas, cantidades_valores, color='skyblue')
plt.xlabel('Tiendas')
plt.ylabel('Ventas Totales $ Vendidas')
plt.title('Ventas Totales de Unidades Vendidas por Tienda  $ (Categoría: Muebles) / Mayor Categoria Vendida')

# Mostrar el valor en la parte superior de cada barra
for i, v in enumerate(cantidades_valores):
  # Adjust the vertical position for better visualization with larger values
    plt.text(i, v + 1000000, f'{v:,.0f}', ha='center', va='bottom') # Format for better readability
plt.show()

# %%
########################################### Categoria menos Vendida en Cada / Tienda ###################################333

import matplotlib.pyplot as plt
import numpy as np

data = {
    'Tienda 1': {'categoria_menos_vendida': 'Artículos para el hogar', 'ventas_totales': 12698400.00, 'cantidad': 171},
    'Tienda 2': {'categoria_menos_vendida': 'Artículos para el hogar', 'ventas_totales': 14746900.00, 'cantidad': 181},
    'Tienda 3': {'categoria_menos_vendida': 'Artículos para el hogar', 'ventas_totales': 15060000.00, 'cantidad': 177},
    'Tienda 4': {'categoria_menos_vendida': 'Instrumentos musicales', 'ventas_totales': 75102400.00, 'cantidad': 170}
}

tiendas = list(data.keys())
cantidades = [data[tienda] ['cantidad'] for tienda in tiendas]
categoria = ['Artículos para el hogar', 'Artículos para el hogar', 'Artículos para el hogar', 'Instrumentos musicales']

# Nombres de las tiendas
#tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4' ]

plt.figure(figsize=(10, 7)) # Increased figure size for better readability
bars = plt.bar(tiendas, cantidades, color='skyblue') # Store the bar objects

# Valores de facturación
#valores = [data['Tienda 1'], data['Tienda 2'], data['Tienda 3'], data['Tienda 4']]

#plt.figure(figsize=(8, 6))
#plt.bar(tiendas, cantidades, color='skyblue')
plt.xlabel('Tiendas')
plt.ylabel('Cantidad de Unidades Vendidas')
plt.title('Categoria en Menor Cantidad Vendida')
# Mostrar el valor en la parte superior de cada barra para el primer plot
#for i, v in enumerate(cantidades):
    #plt.text(i, v + 10, str(v), ha='center', va='bottom')

# Mostrar el valor en la parte superior de cada barra
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + yval*0.02, f'{yval:,.0f}', ha='center', va='bottom') # Adjust vertical position relative to bar height

# Mostrar la categoria debajo de cada barra
for i, cat in enumerate(categoria):
    plt.text(i, cantidades[i] - cantidades[i]*0.05, cat, ha='center', va='top', rotation=45) # Position text below the bar and rotate for better fit

plt.tight_layout() # Adjust layout to prevent labels from overlapping
plt.show()

########################################### por Valor Total ###################################333

#tiendas = list(data.keys())
cantidades_valores = [data[tienda]['ventas_totales'] for tienda in tiendas]
categoria = ['Artículos para el hogar', 'Artículos para el hogar', 'Artículos para el hogar', 'Instrumentos musicales']

plt.figure(figsize=(10, 7)) # Increased figure size for better readability
bars = plt.bar(tiendas, cantidades_valores, color='skyblue') # Store the bar objects
#plt.figure(figsize=(8, 6))
#plt.bar(tiendas, cantidades_valores, categoria, color='skyblue')
plt.xlabel('Tiendas')
plt.ylabel('Ventas Totales $ Vendidas')
plt.title('Categoria con Menor ventas totales por Tienda')



# Mostrar el valor en la parte superior de cada barra
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + yval*0.02, f'{yval:,.0f}', ha='center', va='bottom') # Adjust vertical position relative to bar height

# Mostrar la categoria debajo de cada barra
for i, cat in enumerate(categoria):
    plt.text(i, cantidades_valores[i] - cantidades_valores[i]*0.05, cat, ha='center', va='top', rotation=45) # Position text below the bar and rotate for better fit

plt.tight_layout() # Adjust layout to prevent labels from overlapping

# Mostrar el valor en la parte superior de cada barra
#for i, v in enumerate(cantidades_valores):
  # Adjust the vertical position for better visualization with larger values
    #plt.text(i, v + 1000000, f'{v:,.0f}', ha='center', va='bottom') # Format for better readability

# Mostrar la categoria en la parte superior de cada barra
#for i, v in enumerate(categoria):
    #plt.text(i, v + 10, v, ha='center', va='bottom')


plt.show()

# %% [markdown]
# ### **3. Calificación promedio de la tienda**
#
# * El promedio de clasificación de los clientes en la tienda 1 es: 3.976685036032217
# * El promedio de clasificación de los clientes en la tienda 2 es: 4.037303942348453
# * El promedio de clasificación de los clientes en la tienda 3 es: 4.048325561678677
# * El promedio de clasificación de los clientes en la tienda 4 es: 3.9957591178965224
#
#
# El promedio de clasificación de los clientes en las 4 tiendas es: 4.014520402755696
#
#
# * La tienda con el menor promedio de clasificacion es: Tienda 1 con  3.976685036032217
# * La tienda con el mayor promedio de clasificacion es: Tienda 3 con  4.048325561678677

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the scatter plot
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4', 'Tiendas combinadas']
promedios_clasificacion = [3.976685036032217, 4.037303942348453, 4.048325561678677, 3.9957591178965224, 4.014520402755696]

# Create the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(tiendas, promedios_clasificacion, color='skyblue', s=100) # s is for marker size

# Add titles and labels
plt.title('Promedio de Clasificación por Tienda')
plt.xlabel('Tiendas')
plt.ylabel('Promedio de Clasificación')
plt.ylim(3.9, 4.1) # Adjust y-axis limits for better visualization

# Add text labels for each point
for i, txt in enumerate(promedios_clasificacion):
    plt.annotate(f'{txt:.3f}', (tiendas[i], promedios_clasificacion[i]), textcoords="offset points", xytext=(0,10), ha='center')

# Show the plot
plt.tight_layout()
plt.grid(True)
plt.show()

# %%
# prompt: crear diagrama interativo, para graficar los siguientes datos, promedio de clasificacion, El menor promedio de clasificacion:  Tienda 1 con  3.976685036032217, El mayor promedio de clasificacion: Tienda 3 con 4.048325561678677, incluir en el diagrama los valores y el nombre de la tienda

# !pip install altair

import altair as alt

# Data for the interactive chart
data = pd.DataFrame({
    'Tienda': ['Tienda 1', 'Tienda 3'],
    'Promedio_Clasificacion': [3.976685036032217, 4.048325561678677]
})

# Create the interactive bar chart
chart = alt.Chart(data).mark_bar().encode(
    x=alt.X('Tienda:N', title='Tienda'),
    y=alt.Y('Promedio_Clasificacion:Q', title='Promedio de Clasificación'),
    tooltip=['Tienda', 'Promedio_Clasificacion']
).properties(
    title='Promedio de Clasificación por Tienda (Menor y Mayor)'
)

# Add text labels on top of the bars
text = chart.mark_text(
    align='center',
    baseline='bottom',
    dy=-5 # Adjust vertical position of text
).encode(
    text=alt.Text('Promedio_Clasificacion:Q', format='.3f') # Format the text to 3 decimal places
)

# Combine the bar and text layers
final_chart = chart + text

# Display the chart
final_chart
# Out:
# ...
# alt.LayerChart(...)

# %% [markdown]
# ## **4. Productos más y menos vendidos**
#
# * El producto más vendida en Tienda_1 es 'TV LED UHD 4K' con ventas totales de 142150200.00 con una candidad de 60 unidades
# * El producto más vendida en Tienda_2 es 'Iphone 15' con ventas totales de 113225800.00 con una candidad de 55 unidades
# * El producto más vendida en Tienda_3 es 'Refrigerador' con ventas totales de 99889700.00 con una candidad de 50 unidades
# * El producto más vendida en Tienda_4 es 'Iphone 15' con ventas totales de 96697500.00 con una candidad de 48 unidades
#
#
# * El producto menos vendida en Tienda_1 es 'Cuerda para saltar' con ventas totales de 652800.00 con una candidad de 40 unidades
# * El producto menos vendida en Tienda_2 es 'Cubo mágico 8x8' con ventas totales de 643600.00 con una candidad de 45 unidades
# * El producto menos vendida en Tienda_3 es 'Cubo mágico 8x8' con ventas totales de 640400.00 con una candidad de 44 unidades
# * El producto menos vendida en Tienda_4 es 'Cuerda para saltar' con ventas totales de 704800.00 con una candidad de 43 unidades
#
# * El producto **más vendida en todas las tiendas combinadas** es 'TV LED UHD 4K' con ventas totales de 432489600.00 con una cantidad de 187 unidades
# * El producto **menos vendida en todas las tiendas combinadas** es 'Cubo mágico 8x8' con ventas totales de 2729300.00 con una cantidad de 180 unidades
#
#
# * La tienda con la menor  ventas por producto es: Tienda 4 con una cantidad ventas totales de  1038375700.0
# * La tienda con la mayor  ventas por producto es: Tienda 1 con una cantidad ventas totales de  1150880400.0
#
#
#
#
# * La tienda con la **menor cantidad ventas por producto** es: **Tienda 4** con una cantidad ventas totales de  **2358**
# * La tienda con la **mayor cantidad ventas por producto** es: **Tienda 1** con una cantidad ventas totales de  **2359**

# %%
# !pip install altair

import altair as alt
import pandas as pd

# Data for the interactive chart
data = pd.DataFrame({
    'Producto': [
        'TV LED UHD 4K (Tienda 1)', 'Iphone 15 (Tienda 2)', 'Refrigerador (Tienda 3)',
        'Iphone 15 (Tienda 4)', 'TV LED UHD 4K (Combinada)', 'Cuerda para saltar (Tienda 1)',
        'Cubo mágico 8x8 (Tienda 2)', 'Cubo mágico 8x8 (Tienda 3)',
        'Cuerda para saltar (Tienda 4)', 'Cubo mágico 8x8 (Combinada)'
    ],
    'Ventas_Totales': [
        142150200.00, 113225800.00, 99889700.00, 96697500.00, 432489600.00,
        652800.00, 643600.00, 640400.00, 704800.00, 2729300.00
    ]
})

# Create the interactive bar chart
chart = alt.Chart(data).mark_bar().encode(
    x=alt.X('Producto:N', title='Producto'),
    y=alt.Y('Ventas_Totales:Q', title='Ventas Totales'),
    tooltip=['Producto', 'Ventas_Totales']
).properties(
    title='Ventas Totales por Producto (Más y Menos Vendidos)'
)

# Add text labels on top of the bars
text = chart.mark_text(
    align='center',
    baseline='bottom',
    dy=-5 # Adjust vertical position of text
).encode(
    text=alt.Text('Ventas_Totales:Q', format=',.0f') # Format the text with commas and no decimal places
)

# Combine the bar and text layers
final_chart = chart + text

# Display the chart
final_chart
# Out:
# ...
# alt.LayerChart(...)

# %%
import matplotlib.pyplot as plt

categorias = [ 'TV LED UHD 4K (Tienda 1; Cantidad: 60 unidades )', 'Iphone 15 (Tienda 2; Cantidad: 55 unidades )', 'Refrigerador (Tienda 3; Cantidad: 50 unidades)',
        'Iphone 15 (Tienda 4; Cantidad: 48 unidades)', 'TV LED UHD 4K (Tiendas Combinada; Cantidad: 187 unidades)']
ventas_totales = [652800.00, 643600.00, 640400.00, 704800.00, 2729300.00]

plt.figure(figsize=(8, 8))
plt.pie(ventas_totales, labels=categorias, autopct='%1.1f%%', startangle=140)
plt.title('Producto Más Vendido en Cada Tienda')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
import matplotlib.pyplot as plt

categorias = ['Cuerda para saltar (Tienda 1 Cantidad: 40 unidades)',
        'Cubo mágico 8x8 (Tienda 2 Cantidad: 45 unidades)', 'Cubo mágico 8x8 (Tienda 3 Cantidad: 44 unidades)',
        'Cuerda para saltar (Tienda 4 Cantidad: 43 unidades)', 'Cubo mágico 8x8 (Combinada Todas Las Tiendas en   Cantidad: 180 unidades)']
ventas_totales = [652800.00, 643600.00, 640400.00, 704800.00, 2729300.00]

plt.figure(figsize=(8, 8))
plt.pie(ventas_totales, labels=categorias, autopct='%1.1f%%', startangle=140)
plt.title('Producto Menos Vendido en Cada Tienda')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data for the scatter plot
data = pd.DataFrame({
    'Tienda': ['Tienda 1', 'Tienda 4'],
    'Ventas_Totales': [1150880400.0, 1038375700.0],
    'Cantidad_Ventas': [2359, 2358]
})

# Create the scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(data['Cantidad_Ventas'], data['Ventas_Totales'], color='skyblue', s=100) # s is for marker size

# Add titles and labels
plt.title('Ventas Totales vs. Cantidad de Ventas por Tienda')
plt.xlabel('Cantidad de Ventas Totales')
plt.ylabel('Ventas Totales ($)')
plt.grid(True)

# Add text labels for each point
for i, row in data.iterrows():
    plt.annotate(row['Tienda'], (row['Cantidad_Ventas'], row['Ventas_Totales']), textcoords="offset points", xytext=(0,10), ha='center')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# **6. Envio Promedio Por Tienda**
#
# * El Costo Total de Envio para  Tienda 1: 61377900.0 con una cantidad total de envios de 2359 para un promedio total de 26018.60958033065
#
# * El Costo Total de Envio para  Tienda 2: 59485100.0 con una cantidad total de envios de 2359 para un promedio total de 25216.235693090293
#
# * El Costo Total de Envio para  Tienda 3: 58516600.0 con una cantidad total de envios de 2359 para un promedio total de 24805.680373039424
#
# * El Costo Total de Envio para  Tienda 4: 55317400.0 con una cantidad total de envios de 2358 para un promedio total de 23459.457167090754
#
# * El Costo Total de Envio para las 4 tiendas es: 234697000.0 con una cantidad total de envios de 9435 para un promedio total de 24875.145733969264
#
#
#
#
#
# * La tienda con la menor costo de envio total es: Tienda 4 con un costo de envio de 55317400.0
#
# * La tienda con el mayor costo de envio total es: Tienda 1 con un costo de envio de 61377900.0
#
#
#
#
#
# * La tienda con la menor envios total es: Tienda 4 con un cantidad de 2358
#
# * La tienda con el mayor envios total es: Tienda 1 con un cantidad de 2359

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data for the scatter plot
data = pd.DataFrame({
    'Tienda': ['Tienda 1', 'Tienda 4'],
    'Costo_de_Envio': [61377900.0, 55317400.0],
    'Envio_Promedio': [2359, 2358]
})

# Create the scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(data['Envio_Promedio'], data['Costo_de_Envio'], color='red', s=100) # s is for marker size

# Add titles and labels
plt.title('Envio Promedio vs. Costo_de_Envio')
plt.xlabel('Envio_Promedio')
plt.ylabel('Costo_de_Envio ($)')
plt.grid(True)

# Add text labels for each point
for i, row in data.iterrows():
    plt.annotate(row['Tienda'], (row['Envio_Promedio'], row['Costo_de_Envio']), textcoords="offset points", xytext=(0,10), ha='center')
    # Removed the incorrect plt.text line

# Show the plot
plt.tight_layout()
plt.show()

# %%
########################################### Envio Promedio por tienda Menor ###################################333

import matplotlib.pyplot as plt
import numpy as np

data = {
    'Tienda 1': {'Envio': 'Costo ', 'Totales': 61377900.0,'Promedio': 26018.60958033065},
    'Tienda 2': {'Envio': 'Costo', 'Totales': 59485100.0, 'Promedio': 25216.235693090293},
    'Tienda 3': {'Envio': 'Costo', 'Totales': 58516600.0, 'Promedio': 24805.680373039424},
    'Tienda 4': {'envio': 'Costo', 'Totales': 55317400.0 ,'Promedio': 23459.457167090754},
    'Tiendas Combinadas': {'envio': 'Costo', 'Totales': 234697000.0, 'Promedio': 24875.145733969264}
}

tiendas = list(data.keys())
cantidades = [data[tienda] ['Totales'] for tienda in tiendas]
categoria = ['Promedio: 26018.60958033065; Cantidad: 2359', 'Promedio: 25216.235693090293; Cantidad: 2359', 'Promedio:24805.680373039424; Cantidad: 2359', 'Promedio: 23459.457167090754; Cantidad: 2358', 'Promedio:24875.145733969264; Cantidad: 9435']

# Nombres de las tiendas
#tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4' ]

plt.figure(figsize=(10, 7)) # Increased figure size for better readability
bars = plt.bar(tiendas, cantidades, color='skyblue') # Store the bar objects

# Valores de facturación
#valores = [data['Tienda 1'], data['Tienda 2'], data['Tienda 3'], data['Tienda 4']]

#plt.figure(figsize=(8, 6))
#plt.bar(tiendas, cantidades, color='skyblue')
plt.xlabel('Tiendas')
plt.ylabel('Costo de Envio')
plt.title('Costos de Envio promedio')
# Mostrar el valor en la parte superior de cada barra para el primer plot
#for i, v in enumerate(cantidades):
    #plt.text(i, v + 10, str(v), ha='center', va='bottom')

# Mostrar el valor en la parte superior de cada barra
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + yval*0.02, f'{yval:,.0f}', ha='center', va='bottom') # Adjust vertical position relative to bar height

# Mostrar la categoria debajo de cada barra
for i, cat in enumerate(categoria):
    plt.text(i, cantidades[i] - cantidades[i]*0.05, cat, ha='center', va='top', rotation=45) # Position text below the bar and rotate for better fit

plt.tight_layout() # Adjust layout to prevent labels from overlapping
plt.show()

# %% [markdown]
# ANALISIS SOBRE LAS 4 TIENDAS:
#
# las 4 tiendas tienen una buena cantidad de ventas siendo pareja en las 4 tiendas de 2359 y diferente, 2358 unidades siendo muy minima la diferencia, podemos decir que venden en la misma medida;
#
# la unica diferencia marcada en las 4 tiendas es la facturacion, de** $112.504.700** entre la tienda de menor facturación Tienda 4 y la de mayor facturacion Tienda 1.
#
# **Tienda 1**= $1.150.880.400 - **Tienda 4:** 1.038.375.700 = **$ 112.504.700**
#
# Se recomienda, antes de proceder al cierre de alguna tienda, como la tienda 4, determinar:
# * por que los productos que mas vende son de menor valor,
# * como estan ubicadas las estanterias, *
# * en que zona esta ubicada esta tienda,
# * que capacidad adquisitiva tienen las personas del sector,
# * y determinar su volumen de ventas, mas alla de la facturacion total.
# * que tan importante es la tienda para el sector.
#
# Ademas se recomienda revisar la clasificacion de la Tienda 1, que por que es la menor clasificacion con respecto a sus clientes, aunque es la que tiene la facturacion y ventas mas alta. Determinar cual es la falencia de esta mala calificacion?
#
# Ademas, determinar los productos con mayor valor, sus categorias y ubicacion en la Tienda.
#
# Tambien, revisar por que la Tienda 3 tiene tan buena calificacion, determinar estos buenos resultados a que se deben y tratar de implementarlos en las otras tiendas.
#
#
# **Analisis para el Señor Joao:**
#
# Señor Joao sus 4 tiendas tienen un buen volumen de ventas, de envios, la unica diferencia es el precio del o los articulos comprados en cada tienda, siendo la facturacion la diferencia mas marcada, dando una diferencia de:
#
# **Tienda 1**= $1.150.880.400 - **Tienda 4:** 1.038.375.700 = **$ 112.504.700**
#
# No le podria recomendar cerrar una u otra tienda solo por la facturacion, siendo que las ventas en las 4 tiendas en cuestion de cantidad, ocilan entre 2358 y 2359, cual se puede determinar que han vendido las mismas cantidades.
#
# Asi que tienen un buen volumen de ventas, y siendo que estas 4 tiendas, tienen las mismas categorias y productos, esta diferencia es oscilante y no constante.
#
# y por lo tanto no podria determinar una baja productividad en la tienda, sino una condicion de costo de compra, sector, lugar, capacidad y necesidad del momento.
#
# ademas al desconocer la ubicacion, de las 4 tiendas, el cierre de una podria afectar fuertemente el costo de facturacion total del negocio, por que se podria cerrar en un punto especifico y donde no hay mas negocios cerca.
#
# Adjunto informes:
#
#         **FACTURACION POR TIENDA**
#
#         ![facturacion 4.png](data:image/png;base64,...)![facturacion resumen.png](data:image/png;base64,...)
#
#
#
#
# #                              VENTAS POR CATEGORIAS
#
# ![ventas totales.png](data:image/png;base64,...)![ventas totales por unidades.png](data:image/png;base64,...)![distribucion de ventas por categoria.png](data:image/png;base64,...)
#
#
#                        ** CLASIFICACION PROMEDIO POR TIENDA**
#
#                        ![clasificacion promedio.png](data:image/png;base64,...)
#
#
#                           **PRODUCTO MAS Y MENOS VENDIDO**
#
#
#                                              ![producto mas vendido en cada tienda.png](data:image/png;base64,...)![producto menos vendido.png](data:image/png;base64,...)![ventas totales vs cantidades totales.png](data:image/png;base64,...)
#
#
#
#
#                                           **  ENVIO PORMEDIO POR TIENDA**
#
#
#                                                           ![costo de envio promedio.png](data:image/png;base64,...)
